# %% [markdown]
# ### Database Troubleshooting
#
# Resources, tips, and utilities for all those times when I choke the database.

# %% [markdown]
# [Finding and killing long running queries on PostgreSQL](https://medium.com/little-programming-joys/finding-and-killing-long-running-queries-on-postgres-7c4f0449e86d)

# %%
# IMPORTS
import geopandas as gpd
import pandas as pd

# import os
# import urllib.request
# import requests
# import shutil
# from pathlib import Path
# from zipfile import ZipFile

import matplotlib.pyplot as plt
from matplotlib import pyplot

# import folium

# from shapely.geometry import Point, Polygon

# from geopandas.tools import overlay

# from geopy.geocoders import Nominatim # for geocoding

# a few more imports specfic to the database process
import geoalchemy2 
import getpass

import psycopg2
import numpy
from psycopg2.extensions import adapt, register_adapter, AsIs

from sqlalchemy import create_engine

# %%
# pip install GeoAlchemy2

# %%
# import geoalchemy2

# %%
# get user password for connecting to the db
mypasswd = getpass.getpass()
# Out:
# ········

# %%
# set up db connection
conn = psycopg2.connect(database = 'cappsds_psmd39', 
                              user = 'psmd39', 
                              host = 'pgsql.dsa.lan',
                              password = mypasswd)

# %%
# establish cursor and read the existing tables
cursor = conn.cursor()

cursor.execute("""SELECT relname FROM pg_class WHERE relkind='r'
                  AND relname !~ '^(pg_|sql_)';""") # "rel" is short for relation.

tables = [i[0] for i in cursor.fetchall()] # A list() of tables.
tables.sort()
tables
# Out:
# ['country_borders',
#  'gadm_admin_borders',
#  'geonames_feature',
#  'msorfailedgeocoding',
#  'spatial_ref_sys',
#  'stlchildcare',
#  'stlnonrestrictedresidential',
#  'stlnonrestrictedresparcels',
#  'stlpubschools',
#  'stlpvtschools',
#  'stlresparcels',
#  'stlrestrictedflat',
#  'stlsexoffenders',
#  'stlzoning']

# %%
# create sql statement and pull from db into a geopandas dataframe
sql = "SELECT * FROM msorfailedgeocoding ORDER BY index LIMIT 25;"
df1 = pd.read_sql(sql, conn)
# gpd_childcare = gpd_childcare.drop(columns='geometry') # drop the duplicate geometry column
df1
# Out:
#     index                  name                       address         city  \
# 0      10       ABDI, IBRAHIM A        3764 CHIPPEWA ST APT 8  SAINT LOUIS
# 1      18  ABERNATHY, RANDELL L      3866 S SPRING AVE APT 1S  SAINT LOUIS
# 2      40    ACKLEY, CLIFFORD D           3329 LAWN AVE APT 4  SAINT LOUIS
# 3      41    ACKLEY, CLIFFORD D           3329 LAWN AVE APT 4  SAINT LOUIS
# 4      99   ADAMS, QUINDARRYL L     4133 CLEVELAND AVE APT 1W  SAINT LOUIS
# 5     109      ADAMS, WILLIAM J          5340 GRANT ST FL 2ND  SAINT LOUIS
# 6     135       AGERS, JUSTIN L       3764 CHIPPEWA ST APT 12  SAINT LOUIS
# 7     196    ALBRITTON, BRIAN K           9756 LILAC DR APT C  SAINT LOUIS
# 8     197    ALBRITTON, BRIAN K           9756 LILAC DR APT C  SAINT LOUIS
# 9     212    ALDRIDGE, SAMUEL A     120 W CATALAN AVE APT 201     ST LOUIS
# 10    213    ALDRIDGE, SAMUEL A     120 W CATALAN AVE APT 201     ST LOUIS
# ...

# %%
# create sql statement and pull from db into a geopandas dataframe
sql = "SELECT * FROM msorfailedgeocoding ORDER BY index DESC LIMIT 25;"
df2 = pd.read_sql(sql, conn)
# gpd_childcare = gpd_childcare.drop(columns='geometry') # drop the duplicate geometry column
df2
# Out:
#     index                name                        address         city  st  \
# 0   26102   ZWEIFEL, JUDITH A  4447 CASTLEMAN AVE APT 1 WEST  SAINT LOUIS  MO
# 1   26101   ZWEIFEL, JUDITH A  4447 CASTLEMAN AVE APT 1 WEST  SAINT LOUIS  MO
# 2   26100   ZWEIFEL, JUDITH A  4447 CASTLEMAN AVE APT 1 WEST  SAINT LOUIS  MO
# 3   26011    YOUNG, WILLIAM R           159 SHEPLEY DR APT 2  SAINT LOUIS  MO
# 4   26006     YOUNG, TYRONE F           4962 THEKLA AVE FL 1  SAINT LOUIS  MO
# 5   25994       YOUNG, MARVIN          3922 GUSTINE AVE FL 1  SAINT LOUIS  MO
# 6   25993       YOUNG, MARVIN          3922 GUSTINE AVE FL 1  SAINT LOUIS  MO
# 7   25992       YOUNG, MARVIN          3922 GUSTINE AVE FL 1  SAINT LOUIS  MO
# 8   25991       YOUNG, MARVIN          3922 GUSTINE AVE FL 1  SAINT LOUIS  MO
# 9   25981         YOUNG, JOHN             2107 E COLLEGE AVE  SAINT LOUIS  MO
# 10  25966  YOUNG, FREDERICK G           205 N 9TH ST APT 814  SAINT LOUIS  MO
# ...

# %%
# Set up database connection engine
engine = create_engine('postgresql://psmd39:Mizzou23?@pgsql.dsa.lan:5432/cappsds_psmd39', echo=False)

# GeoDataFrame to PostGIS
df1.to_sql(
    con=engine,
    name="test1",
    if_exists='replace'
)

# %%
df2.to_sql(
    con=engine,
    name="test1",
    if_exists='append'
)

# %%
# create sql statement and pull from db into a geopandas dataframe
sql = "SELECT * FROM test1 ORDER BY index;"
dftest1 = pd.read_sql(sql, conn)
# gpd_childcare = gpd_childcare.drop(columns='geometry') # drop the duplicate geometry column
dftest1
# Out:
#     level_0  index                  name                        address  \
# 0         0     10       ABDI, IBRAHIM A         3764 CHIPPEWA ST APT 8
# 1         1     18  ABERNATHY, RANDELL L       3866 S SPRING AVE APT 1S
# 2         2     40    ACKLEY, CLIFFORD D            3329 LAWN AVE APT 4
# 3         3     41    ACKLEY, CLIFFORD D            3329 LAWN AVE APT 4
# 4         4     99   ADAMS, QUINDARRYL L      4133 CLEVELAND AVE APT 1W
# 5         5    109      ADAMS, WILLIAM J           5340 GRANT ST FL 2ND
# 6         6    135       AGERS, JUSTIN L        3764 CHIPPEWA ST APT 12
# 7         7    196    ALBRITTON, BRIAN K            9756 LILAC DR APT C
# 8         8    197    ALBRITTON, BRIAN K            9756 LILAC DR APT C
# 9         9    212    ALDRIDGE, SAMUEL A      120 W CATALAN AVE APT 201
# 10       10    213    ALDRIDGE, SAMUEL A      120 W CATALAN AVE APT 201
# 11       11    214    ALDRIDGE, SAMUEL A      120 W CATALAN AVE APT 201
# ...

# %%
# PLACEHOLDER TO DROP A TABLE IF NECESSARY

engine_drop = create_engine('postgresql://psmd39:Mizzou23?@pgsql.dsa.lan:5432/cappsds_psmd39', echo=False)
result = engine_drop.execute('DROP TABLE IF EXISTS test1;')
engine_drop.dispose()

# %%
#close connection to the db
conn.close()
# engine.dispose()
