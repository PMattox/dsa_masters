# %% [markdown]
# ### Database Troubleshooting
#
# Resources, tips, and utilities for all those times when I choke the database.

# %% [markdown]
# [Finding and killing long running queries on PostgreSQL](https://medium.com/little-programming-joys/finding-and-killing-long-running-queries-on-postgres-7c4f0449e86d)

# %%
# IMPORTS
import geopandas as gpd
import pandas as pd

# import os
# import urllib.request
# import requests
# import shutil
# from pathlib import Path
# from zipfile import ZipFile

import matplotlib.pyplot as plt
from matplotlib import pyplot

# import folium

# from shapely.geometry import Point, Polygon

# from geopandas.tools import overlay

# from geopy.geocoders import Nominatim # for geocoding

# a few more imports specfic to the database process
# import geoalchemy2 
import getpass

import psycopg2
import numpy
from psycopg2.extensions import adapt, register_adapter, AsIs

from sqlalchemy import create_engine

# %%
# pip install GeoAlchemy2
# Out:
# Collecting GeoAlchemy2==0.11.0
#   Downloading https://files.pythonhosted.org/packages/5e/3b/2fe641f8ab19b795acc3a7589cec161884921c9d885903d11c34722fc1b6/GeoAlchemy2-0.11.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 971kB/s eta 0:00:011
# Requirement already satisfied: SQLAlchemy>=1.1 in /opt/conda/lib/python3.7/site-packages (from GeoAlchemy2==0.11.0) (1.4.22)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from GeoAlchemy2==0.11.0) (21.0)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" in /opt/conda/lib/python3.7/site-packages (from SQLAlchemy>=1.1->GeoAlchemy2==0.11.0) (1.1.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from SQLAlchemy>=1.1->GeoAlchemy2==0.11.0) (4.6.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->GeoAlchemy2==0.11.0) (2.4.7)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->SQLAlchemy>=1.1->GeoAlchemy2==0.11.0) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->SQLAlchemy>=1.1->GeoAlchemy2==0.11.0) (3.5.0)
# Installing collected packages: GeoAlchemy2
#   Found existing installation: GeoAlchemy2 0.10.2
#     Uninstalling GeoAlchemy2-0.10.2:
#       Successfully uninstalled GeoAlchemy2-0.10.2
# Successfully installed GeoAlchemy2-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install GeoAlchemy2==0.10.2

# %%
import geoalchemy2

# %%
# get user password for connecting to the db
mypasswd = getpass.getpass()
# Out:
# ········

# %%
# set up db connection
conn = psycopg2.connect(database = 'cappsds_psmd39', 
                              user = 'psmd39', 
                              host = 'pgsql.dsa.lan',
                              password = mypasswd)


# establish cursor and read the existing tables
cursor = conn.cursor()

cursor.execute("""SELECT relname FROM pg_class WHERE relkind='r'
                  AND relname !~ '^(pg_|sql_)';""") # "rel" is short for relation.

tables = [i[0] for i in cursor.fetchall()] # A list() of tables.
tables.sort()
tables
# Out:
# ['country_borders',
#  'gadm_admin_borders',
#  'geonames_feature',
#  'spatial_ref_sys',
#  'stlchildcare',
#  'stlnonrestrictedresidential',
#  'stlnonrestrictedresparcels',
#  'stlpubschools',
#  'stlpvtschools',
#  'stlresparcels',
#  'stlrestrictedflat',
#  'stlsexoffenders',
#  'stlzoning']

# %%
# check out the active connections
cursor.execute("""SELECT count(*),state FROM pg_stat_activity GROUP BY 2;""")
# cursor.execute("""SELECT * FROM pg_stat_activity WHERE state = 'active';""")
# cursor.execute("""SELECT * FROM pg_stat_activity WHERE state = 'idle';""")
# cursor.execute("""SELECT
#                       pid,
#                       now() - pg_stat_activity.query_start AS duration,
#                       query,
#                       state
#                     FROM pg_stat_activity
#                     WHERE (now() - pg_stat_activity.query_start) > interval '5 minutes';""")

# cursor.execute("""SELECT pg_terminate_backend(pid) FROM pg_stat_activity""")
# cursor.execute("""SELECT pg_cancel_backend(pid);""")

cursor.fetchall()
# Out:
# [(21, None), (1, 'active')]

# %%
cursor.execute("""GRANT SELECT ON geospatial.gadm_admin_borders TO psmd39;""")
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# <ipython-input-26-6b35b1d6d7e6> in <module>
# ----> 1 cursor.execute("""GRANT SELECT ON geospatial.gadm_admin_borders TO psmd39;""")
#
# InsufficientPrivilege: permission denied for relation gadm_admin_borders

# %%
cursor.execute("""ALTER TABLE msorfailedgeocodingv2 RENAME TO msorfailedgeocodingv2_basic;""")
msorfailedgeocoding_basic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0ee3a025bb9f> in <module>
#       1 cursor.execute("""ALTER TABLE msorfailedgeocodingv2 RENAME TO msorfailedgeocodingv2_basic;""")
# ----> 2 msorfailedgeocoding_basic
#
# NameError: name 'msorfailedgeocoding_basic' is not defined

# %%
# RENAME A TABLE

engine = create_engine('postgresql://psmd39:Mizzou23?@pgsql.dsa.lan:5432/cappsds_psmd39', echo=False)
result = engine.execute('ALTER TABLE stlsexoffenders RENAME TO stlsexoffenders_basic;')

# %%
# PLACEHOLDER TO DROP A TABLE IF NECESSARY

engine = create_engine('postgresql://psmd39:Mizzou23?@pgsql.dsa.lan:5432/cappsds_psmd39', echo=False)
result = engine.execute('DROP TABLE IF EXISTS public.stlsexoffenders;')

# %%
# PLACEHOLDER TO DROP A TABLE IF NECESSARY

engine = create_engine('postgresql://psmd39:Mizzou23?@pgsql.dsa.lan:5432/cappsds_psmd39', echo=False)
result = engine.execute('DROP INDEX stlsexoffenders.idx_stlsexoffenders_geometry;')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotSupported                       Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1771                     self.dialect.do_execute(
# -> 1772                         cursor, statement, parameters, context
#    1773                     )
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# FeatureNotSupported: cross-database references are not implemented: "public.stlsexoffenders.idx_stlsexoffenders_geometry"
#
#
# The above exception was the direct cause of the following exception:
#
# NotSupportedError                         Traceback (most recent call last)
# <ipython-input-15-20417683d628> in <module>
#       2
#       3 engine = create_engine('postgresql://psmd39:Mizzou23?@pgsql.dsa.lan:5432/cappsds_psmd39', echo=False)
# ----> 4 result = engine.execute('DROP INDEX public.stlsexoffenders.idx_stlsexoffenders_geometry;')
#
# <string> in execute(self, statement, *multiparams, **params)
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     388         if not skip_warning:
#     389             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 390         return fn(*args, **kwargs)
#     391
#     392     doc = func.__doc__ is not None and func.__doc__ or ""
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3106         """
#    3107         connection = self.connect(close_with_result=True)
# -> 3108         return connection.execute(statement, *multiparams, **params)
#    3109
#    3110     @util.deprecated_20(
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1251                 params,
#    1252                 _EMPTY_EXECUTION_OPTS,
# -> 1253                 future=False,
#    1254             )
#    1255
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1552             execution_options,
#    1553             statement,
# -> 1554             distilled_parameters,
#    1555         )
#    1556
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1813         except BaseException as e:
#    1814             self._handle_dbapi_exception(
# -> 1815                 e, statement, parameters, cursor, context
#    1816             )
#    1817
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1994             elif should_wrap:
#    1995                 util.raise_(
# -> 1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#    1998             else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
#    1771                     self.dialect.do_execute(
# -> 1772                         cursor, statement, parameters, context
#    1773                     )
#    1774
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# NotSupportedError: (psycopg2.errors.FeatureNotSupported) cross-database references are not implemented: "public.stlsexoffenders.idx_stlsexoffenders_geometry"
#
# [SQL: DROP INDEX public.stlsexoffenders.idx_stlsexoffenders_geometry;]
# (Background on this error at: https://sqlalche.me/e/14/tw8g)

# %%
DROP INDEX table_name.index_name;

# %%
cursor.execute("""SELECT relname FROM pg_class WHERE relkind='r'
                  AND relname !~ '^(pg_|sql_)';""") # "rel" is short for relation.

tables = [i[0] for i in cursor.fetchall()] # A list() of tables.
tables.sort()
tables
# Out:
# ['country_borders',
#  'gadm_admin_borders',
#  'geonames_feature',
#  'spatial_ref_sys',
#  'stlchildcare',
#  'stlnonrestrictedresidential',
#  'stlnonrestrictedresparcels',
#  'stlpubschools',
#  'stlpvtschools',
#  'stlresparcels',
#  'stlrestrictedflat',
#  'stlzoning']

# %%
conn.close()

# %%
# test to make sure the load actually worked
# query the table and read data into a geodf 
sql = "select * from stlsexoffenders;"
db_test_out = pd.read_sql(sql, conn)
db_test_out
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# UndefinedTable: relation "stlsexoffenders" does not exist
# LINE 1: select * from stlsexoffenders;
#                       ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-21-18ed113987c8> in <module>
#       2 # query the table and read data into a geodf
#       3 sql = "select * from stlsexoffenders;"
# ----> 4 db_test_out = pd.read_sql(sql, conn)
#       5 db_test_out
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     606             coerce_float=coerce_float,
#     607             parse_dates=parse_dates,
# --> 608             chunksize=chunksize,
#     609         )
#     610
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2114
#    2115         args = _convert_params(sql, params)
# -> 2116         cursor = self.execute(*args)
#    2117         columns = [col_desc[0] for col_desc in cursor.description]
#    2118
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql 'select * from stlsexoffenders;': relation "stlsexoffenders" does not exist
# LINE 1: select * from stlsexoffenders;
#                       ^

# %%
db_test_out.to_csv(r'msorfailedgeocodingv2_basic.csv', index = False)

# %% [markdown]
# ## Read data from CSV, convert to geodataframe, load to PostGIS

# %%
df = pd.read_csv('data/stlsexoffenders.csv')
df.head()
# Out:
#    randomid                 name             address         city  st    zip  \
# 0     30626  ABERNATHY, STEVIE A      133 BAYVIEW DR  SAINT LOUIS  MO  63135
# 1     36296    ABRAMS, NORVELL L      1946 HEBERT ST  SAINT LOUIS  MO  63107
# 2     19536      ADAMS, BRYANT A  7614 FLORISSANT RD  SAINT LOUIS  MO  63121
# 3      6750      ADAMS, DAMEON A       8022 JOEL AVE  SAINT LOUIS  MO  63123
# 4     24283      ADAMS, GEORGE N  9921 HEATHERTON DR  SAINT LOUIS  MO  63123
#
#           county                          offense     offense_city  \
# 0       ST LOUIS         STATUTORY RAPE-2ND DEGRE        ST PETERS
# 1  ST LOUIS CITY             ATTEMPT SEXUAL ABUSE         PAGEDALE
# 2       ST LOUIS  STAT RAPE-1ST DEG-PERS UNDER 14         ST LOUIS
# 3       ST LOUIS            CHILD MOLESTATION-1ST    ST LOUIS CITY
# 4       ST LOUIS          CHILD MOLEST-1ST DEGREE  ST LOUIS COUNTY
#
#   offense_state  ... compliant  tier offense_date conviction_date  \
# 0            MO  ...         Y     3   2014-01-26      2015-12-18
# 1            MO  ...         Y     2   2002-10-14      2003-02-21
# 2            MO  ...         Y     3   2005-09-18      2006-10-06
# 3            MO  ...         Y     3   1996-09-01      1997-07-29
# 4            MO  ...         Y     3   2007-01-01      2017-06-15
#
#    confinement_release_date probation/parole_release_date  \
# 0                2019-08-23           2023-08-09 00:00:00
# 1                2006-10-14           2006-10-14 00:00:00
# 2                       NaN                           NaN
# 3                1998-01-22                           NaN
# 4                       NaN                           NaN
#
#   offender_age_at_time_of_offense        lat       long  \
# 0                              22  38.744944 -90.290619
# 1                              29  38.654602 -90.201029
# 2                              17  38.710232 -90.301116
# 3                              18  38.564085 -90.313727
# 4                              55  38.539049 -90.354750
#
#                                        geometry
# 0   POINT (-90.29061867340511 38.7449439570314)
# 1  POINT (-90.20102902857143 38.65460202857142)
# 2  POINT (-90.30111572682809 38.71023188062727)
# 3  POINT (-90.31372717702361 38.56408510964898)
# 4  POINT (-90.35474961156422 38.53904943784296)
#
# [5 rows x 23 columns]

# %%
from shapely.geometry import Point, Polygon

# create the 'geometry' column for the geodataframe
geometry = [Point(xy) for xy in zip(df['long'], df['lat'])]
# generate the geodataframe using the msor df + the geometry info
# set the CRS (in degrees) as part of this process
msor_db = gpd.GeoDataFrame(df, geometry = geometry, crs=4326)

# %%
msor_db.head()
# Out:
#    randomid                 name             address         city  st    zip  \
# 0     30626  ABERNATHY, STEVIE A      133 BAYVIEW DR  SAINT LOUIS  MO  63135
# 1     36296    ABRAMS, NORVELL L      1946 HEBERT ST  SAINT LOUIS  MO  63107
# 2     19536      ADAMS, BRYANT A  7614 FLORISSANT RD  SAINT LOUIS  MO  63121
# 3      6750      ADAMS, DAMEON A       8022 JOEL AVE  SAINT LOUIS  MO  63123
# 4     24283      ADAMS, GEORGE N  9921 HEATHERTON DR  SAINT LOUIS  MO  63123
#
#           county                          offense     offense_city  \
# 0       ST LOUIS         STATUTORY RAPE-2ND DEGRE        ST PETERS
# 1  ST LOUIS CITY             ATTEMPT SEXUAL ABUSE         PAGEDALE
# 2       ST LOUIS  STAT RAPE-1ST DEG-PERS UNDER 14         ST LOUIS
# 3       ST LOUIS            CHILD MOLESTATION-1ST    ST LOUIS CITY
# 4       ST LOUIS          CHILD MOLEST-1ST DEGREE  ST LOUIS COUNTY
#
#   offense_state  ... compliant  tier offense_date conviction_date  \
# 0            MO  ...         Y     3   2014-01-26      2015-12-18
# 1            MO  ...         Y     2   2002-10-14      2003-02-21
# 2            MO  ...         Y     3   2005-09-18      2006-10-06
# 3            MO  ...         Y     3   1996-09-01      1997-07-29
# 4            MO  ...         Y     3   2007-01-01      2017-06-15
#
#    confinement_release_date probation/parole_release_date  \
# 0                2019-08-23           2023-08-09 00:00:00
# 1                2006-10-14           2006-10-14 00:00:00
# 2                       NaN                           NaN
# 3                1998-01-22                           NaN
# 4                       NaN                           NaN
#
#   offender_age_at_time_of_offense        lat       long  \
# 0                              22  38.744944 -90.290619
# 1                              29  38.654602 -90.201029
# 2                              17  38.710232 -90.301116
# 3                              18  38.564085 -90.313727
# 4                              55  38.539049 -90.354750
#
#                      geometry
# 0  POINT (-90.29062 38.74494)
# 1  POINT (-90.20103 38.65460)
# 2  POINT (-90.30112 38.71023)
# 3  POINT (-90.31373 38.56409)
# 4  POINT (-90.35475 38.53905)
#
# [5 rows x 23 columns]

# %%
# Set up database connection engine
# FORMAT: engine = create_engine('postgresql://user:password@host:5432/')
engine = create_engine('postgresql://psmd39:Mizzou23?@pgsql.dsa.lan:5432/cappsds_psmd39', echo=False)

# GeoDataFrame to PostGIS
msor_db.to_postgis(
    con=engine,
    name="stlsexoffenders_detailed",
    if_exists='replace'
)
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1771                     self.dialect.do_execute(
# -> 1772                         cursor, statement, parameters, context
#    1773                     )
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# DuplicateTable: relation "idx_stlsexoffenders_detailed_geometry" already exists
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-23-dab68bb4a99e> in <module>
#       7     con=engine,
#       8     name="stlsexoffenders_detailed",
# ----> 9     if_exists='replace'
#      10 )
#
# /opt/conda/lib/python3.7/site-packages/geopandas/geodataframe.py in to_postgis(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    1682         """
#    1683         geopandas.io.sql._write_postgis(
# -> 1684             self, name, con, schema, if_exists, index, index_label, chunksize, dtype
#    1685         )
#    1686
#
# /opt/conda/lib/python3.7/site-packages/geopandas/io/sql.py in _write_postgis(gdf, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     438             chunksize=chunksize,
#     439             dtype=dtype,
# --> 440             method=_psql_insert_copy,
#     441         )
#     442
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2877             chunksize=chunksize,
#    2878             dtype=dtype,
# -> 2879             method=method,
#    2880         )
#    2881
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1756             index_label=index_label,
#    1757             schema=schema,
# -> 1758             dtype=dtype,
#    1759         )
#    1760
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in create(self)
#     865                 raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     866         else:
# --> 867             self._execute_create()
#     868
#     869     def _execute_insert(self, conn, keys: list[str], data_iter):
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in _execute_create(self)
#     851         else:
#     852             self.table = self.table.tometadata(self.pd_sql.meta)
# --> 853         self.table.create()
#     854
#     855     def create(self):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/schema.py in create(self, bind, checkfirst)
#     942         if bind is None:
#     943             bind = _bind_or_error(self)
# --> 944         bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#     945
#     946     def drop(self, bind=None, checkfirst=False):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2080
#    2081         """
# -> 2082         visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#    2083
#    2084     @util.deprecated(
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py in traverse_single(self, obj, **kw)
#     518             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     519             if meth:
# --> 520                 return meth(obj, **kw)
#     521
#     522     def iterate(self, obj):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/ddl.py in visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     900         if hasattr(table, "indexes"):
#     901             for index in table.indexes:
# --> 902                 self.traverse_single(index, create_ok=True)
#     903
#     904         if self.dialect.supports_comments and not self.dialect.inline_comments:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py in traverse_single(self, obj, **kw)
#     518             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     519             if meth:
# --> 520                 return meth(obj, **kw)
#     521
#     522     def iterate(self, obj):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/ddl.py in visit_index(self, index, create_ok)
#     931         if not create_ok and not self._can_create_index(index):
#     932             return
# --> 933         self.connection.execute(CreateIndex(index))
#     934
#     935
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1261             )
#    1262         else:
# -> 1263             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1264
#    1265     def _execute_function(self, func, multiparams, params, execution_options):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/ddl.py in _execute_on_connection(self, connection, multiparams, params, execution_options)
#      76     ):
#      77         return connection._execute_ddl(
# ---> 78             self, multiparams, params, execution_options
#      79         )
#      80
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_ddl(self, ddl, multiparams, params, execution_options)
#    1357             None,
#    1358             execution_options,
# -> 1359             compiled,
#    1360         )
#    1361         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1813         except BaseException as e:
#    1814             self._handle_dbapi_exception(
# -> 1815                 e, statement, parameters, cursor, context
#    1816             )
#    1817
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1994             elif should_wrap:
#    1995                 util.raise_(
# -> 1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#    1998             else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
#    1771                     self.dialect.do_execute(
# -> 1772                         cursor, statement, parameters, context
#    1773                     )
#    1774
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.DuplicateTable) relation "idx_stlsexoffenders_detailed_geometry" already exists
#
# [SQL: CREATE INDEX idx_stlsexoffenders_detailed_geometry ON public.stlsexoffenders_detailed USING gist (geometry)]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ## Working with Dr. Scott - Mar 19

# %%
df = pd.read_csv('data/stlsexoffenders.csv')
df.head()
# Out:
#    randomid                 name             address         city  st    zip  \
# 0     30626  ABERNATHY, STEVIE A      133 BAYVIEW DR  SAINT LOUIS  MO  63135
# 1     36296    ABRAMS, NORVELL L      1946 HEBERT ST  SAINT LOUIS  MO  63107
# 2     19536      ADAMS, BRYANT A  7614 FLORISSANT RD  SAINT LOUIS  MO  63121
# 3      6750      ADAMS, DAMEON A       8022 JOEL AVE  SAINT LOUIS  MO  63123
# 4     24283      ADAMS, GEORGE N  9921 HEATHERTON DR  SAINT LOUIS  MO  63123
#
#           county                          offense     offense_city  \
# 0       ST LOUIS         STATUTORY RAPE-2ND DEGRE        ST PETERS
# 1  ST LOUIS CITY             ATTEMPT SEXUAL ABUSE         PAGEDALE
# 2       ST LOUIS  STAT RAPE-1ST DEG-PERS UNDER 14         ST LOUIS
# 3       ST LOUIS            CHILD MOLESTATION-1ST    ST LOUIS CITY
# 4       ST LOUIS          CHILD MOLEST-1ST DEGREE  ST LOUIS COUNTY
#
#   offense_state  ... compliant  tier offense_date conviction_date  \
# 0            MO  ...         Y     3   2014-01-26      2015-12-18
# 1            MO  ...         Y     2   2002-10-14      2003-02-21
# 2            MO  ...         Y     3   2005-09-18      2006-10-06
# 3            MO  ...         Y     3   1996-09-01      1997-07-29
# 4            MO  ...         Y     3   2007-01-01      2017-06-15
#
#    confinement_release_date probation/parole_release_date  \
# 0                2019-08-23           2023-08-09 00:00:00
# 1                2006-10-14           2006-10-14 00:00:00
# 2                       NaN                           NaN
# 3                1998-01-22                           NaN
# 4                       NaN                           NaN
#
#   offender_age_at_time_of_offense        lat       long  \
# 0                              22  38.744944 -90.290619
# 1                              29  38.654602 -90.201029
# 2                              17  38.710232 -90.301116
# 3                              18  38.564085 -90.313727
# 4                              55  38.539049 -90.354750
#
#                                        geometry
# 0   POINT (-90.29061867340511 38.7449439570314)
# 1  POINT (-90.20102902857143 38.65460202857142)
# 2  POINT (-90.30111572682809 38.71023188062727)
# 3  POINT (-90.31372717702361 38.56408510964898)
# 4  POINT (-90.35474961156422 38.53904943784296)
#
# [5 rows x 23 columns]

# %%
from shapely.geometry import Point, Polygon

# create the 'geometry' column for the geodataframe
geometry = [Point(xy) for xy in zip(df['long'], df['lat'])]
# generate the geodataframe using the msor df + the geometry info
# set the CRS (in degrees) as part of this process
msor_db = gpd.GeoDataFrame(df, geometry = geometry, crs=4326) 
msor_db.shape
# Out:
# (3631, 23)

# %%
msor_db_toptwo = msor_db.head(2)
msor_db_toptwo = msor_db_toptwo.set_index('randomid')
msor_db_toptwo
# Out:
#                          name         address         city  st    zip  \
# randomid
# 30626     ABERNATHY, STEVIE A  133 BAYVIEW DR  SAINT LOUIS  MO  63135
# 36296       ABRAMS, NORVELL L  1946 HEBERT ST  SAINT LOUIS  MO  63107
#
#                  county                   offense offense_city offense_state  \
# randomid
# 30626          ST LOUIS  STATUTORY RAPE-2ND DEGRE    ST PETERS            MO
# 36296     ST LOUIS CITY      ATTEMPT SEXUAL ABUSE     PAGEDALE            MO
#
#          victim_gender  ...  compliant tier offense_date  conviction_date  \
# randomid                ...
# 30626                F  ...          Y    3   2014-01-26       2015-12-18
# 36296                F  ...          Y    2   2002-10-14       2003-02-21
#
#          confinement_release_date probation/parole_release_date  \
# randomid
# 30626                  2019-08-23           2023-08-09 00:00:00
# 36296                  2006-10-14           2006-10-14 00:00:00
#
#          offender_age_at_time_of_offense        lat       long  \
# randomid
# 30626                                 22  38.744944 -90.290619
# 36296                                 29  38.654602 -90.201029
#
#                             geometry
# randomid
# 30626     POINT (-90.29062 38.74494)
# 36296     POINT (-90.20103 38.65460)
#
# [2 rows x 22 columns]

# %%
engine = create_engine('postgresql://psmd39:Mizzou23?@pgsql.dsa.lan:5432/cappsds_psmd39', echo=False)

# %%
# GeoDataFrame to PostGIS
msor_db.to_postgis(
    con=engine,
    name="stlsexoffenders",
    if_exists='replace'
)
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1771                     self.dialect.do_execute(
# -> 1772                         cursor, statement, parameters, context
#    1773                     )
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# DuplicateTable: relation "idx_stlsexoffenders_geometry" already exists
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-10-adf53e74c9d9> in <module>
#       3     con=engine,
#       4     name="stlsexoffenders",
# ----> 5     if_exists='replace'
#       6 )
#
# /opt/conda/lib/python3.7/site-packages/geopandas/geodataframe.py in to_postgis(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    1682         """
#    1683         geopandas.io.sql._write_postgis(
# -> 1684             self, name, con, schema, if_exists, index, index_label, chunksize, dtype
#    1685         )
#    1686
#
# /opt/conda/lib/python3.7/site-packages/geopandas/io/sql.py in _write_postgis(gdf, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     438             chunksize=chunksize,
#     439             dtype=dtype,
# --> 440             method=_psql_insert_copy,
#     441         )
#     442
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2877             chunksize=chunksize,
#    2878             dtype=dtype,
# -> 2879             method=method,
#    2880         )
#    2881
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1756             index_label=index_label,
#    1757             schema=schema,
# -> 1758             dtype=dtype,
#    1759         )
#    1760
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in create(self)
#     859             elif self.if_exists == "replace":
#     860                 self.pd_sql.drop_table(self.name, self.schema)
# --> 861                 self._execute_create()
#     862             elif self.if_exists == "append":
#     863                 pass
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in _execute_create(self)
#     851         else:
#     852             self.table = self.table.tometadata(self.pd_sql.meta)
# --> 853         self.table.create()
#     854
#     855     def create(self):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/schema.py in create(self, bind, checkfirst)
#     942         if bind is None:
#     943             bind = _bind_or_error(self)
# --> 944         bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#     945
#     946     def drop(self, bind=None, checkfirst=False):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2080
#    2081         """
# -> 2082         visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#    2083
#    2084     @util.deprecated(
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py in traverse_single(self, obj, **kw)
#     518             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     519             if meth:
# --> 520                 return meth(obj, **kw)
#     521
#     522     def iterate(self, obj):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/ddl.py in visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     900         if hasattr(table, "indexes"):
#     901             for index in table.indexes:
# --> 902                 self.traverse_single(index, create_ok=True)
#     903
#     904         if self.dialect.supports_comments and not self.dialect.inline_comments:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/visitors.py in traverse_single(self, obj, **kw)
#     518             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     519             if meth:
# --> 520                 return meth(obj, **kw)
#     521
#     522     def iterate(self, obj):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/ddl.py in visit_index(self, index, create_ok)
#     931         if not create_ok and not self._can_create_index(index):
#     932             return
# --> 933         self.connection.execute(CreateIndex(index))
#     934
#     935
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1261             )
#    1262         else:
# -> 1263             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1264
#    1265     def _execute_function(self, func, multiparams, params, execution_options):
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/sql/ddl.py in _execute_on_connection(self, connection, multiparams, params, execution_options)
#      76     ):
#      77         return connection._execute_ddl(
# ---> 78             self, multiparams, params, execution_options
#      79         )
#      80
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_ddl(self, ddl, multiparams, params, execution_options)
#    1357             None,
#    1358             execution_options,
# -> 1359             compiled,
#    1360         )
#    1361         if self._has_events or self.engine._has_events:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1813         except BaseException as e:
#    1814             self._handle_dbapi_exception(
# -> 1815                 e, statement, parameters, cursor, context
#    1816             )
#    1817
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1994             elif should_wrap:
#    1995                 util.raise_(
# -> 1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#    1998             else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
#    1771                     self.dialect.do_execute(
# -> 1772                         cursor, statement, parameters, context
#    1773                     )
#    1774
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.DuplicateTable) relation "idx_stlsexoffenders_geometry" already exists
#
# [SQL: CREATE INDEX idx_stlsexoffenders_geometry ON public.stlsexoffenders USING gist (geometry)]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
sql = "select * from stlsexoffenders;"
db_test_out = pd.read_sql(sql, conn)
db_test_out
# Out:
#       randomid                 name             address         city  st  \
# 0        30626  ABERNATHY, STEVIE A      133 BAYVIEW DR  SAINT LOUIS  MO
# 1        36296    ABRAMS, NORVELL L      1946 HEBERT ST  SAINT LOUIS  MO
# 2        19536      ADAMS, BRYANT A  7614 FLORISSANT RD  SAINT LOUIS  MO
# 3         6750      ADAMS, DAMEON A       8022 JOEL AVE  SAINT LOUIS  MO
# 4        24283      ADAMS, GEORGE N  9921 HEATHERTON DR  SAINT LOUIS  MO
# ...        ...                  ...                 ...          ...  ..
# 3626     32101       ZIMMER, ERIC J     5221 S BROADWAY  SAINT LOUIS  MO
# 3627      5596  ZIMMERER, RICHARD K    4600 POEPPING ST  SAINT LOUIS  MO
# 3628     30627  ZIMMERER, RICHARD K    4600 POEPPING ST  SAINT LOUIS  MO
# 3629      8304       ZUNIGA, ANDRES    3644 ROSWELL AVE  SAINT LOUIS  MO
# 3630       312       ZUNIGA, ANDRES    3644 ROSWELL AVE  SAINT LOUIS  MO
#
#         zip         county                            offense  \
# 0     63135       ST LOUIS           STATUTORY RAPE-2ND DEGRE
# 1     63107  ST LOUIS CITY               ATTEMPT SEXUAL ABUSE
# 2     63121       ST LOUIS    STAT RAPE-1ST DEG-PERS UNDER 14
# 3     63123       ST LOUIS              CHILD MOLESTATION-1ST
# 4     63123       ST LOUIS            CHILD MOLEST-1ST DEGREE
# ...     ...            ...                                ...
# 3626  63111  ST LOUIS CITY  PREDATORY CRIMINAL SEXUAL ASSAULT
# 3627  63123  ST LOUIS CITY                     ABUSE OF CHILD
# 3628  63123  ST LOUIS CITY             DEVIATE SEXUAL ASSAULT
# 3629  63116  ST LOUIS CITY            CHILD MOLEST-1ST DEGREE
# 3630  63116  ST LOUIS CITY            CHILD MOLEST-1ST DEGREE
#
#          offense_city offense_state  ... compliant  tier offense_date  \
# 0           ST PETERS            MO  ...         Y     3   2014-01-26
# 1            PAGEDALE            MO  ...         Y     2   2002-10-14
# 2            ST LOUIS            MO  ...         Y     3   2005-09-18
# 3       ST LOUIS CITY            MO  ...         Y     3   1996-09-01
# 4     ST LOUIS COUNTY            MO  ...         Y     3   2007-01-01
# ...               ...           ...  ...       ...   ...          ...
# 3626          CHICAGO            IL  ...         Y     3   1999-12-01
# 3627         ST LOUIS            MO  ...         Y     3   1995-01-07
# 3628         ST LOUIS            MO  ...         Y     3   1995-01-07
# 3629         ST LOUIS            MO  ...         Y     3   1999-12-25
# 3630         ST LOUIS            MO  ...         Y     3   1999-12-25
#
#      conviction_date  confinement_release_date probation/parole_release_date  \
# 0         2015-12-18                2019-08-23           2023-08-09 00:00:00
# 1         2003-02-21                2006-10-14           2006-10-14 00:00:00
# 2         2006-10-06                      None                          None
# 3         1997-07-29                1998-01-22                          None
# 4         2017-06-15                      None                          None
# ...              ...                       ...                           ...
# 3626      2001-05-02                      None                          None
# 3627      1995-10-10                      None                          None
# 3628      1995-10-10                2009-03-25                          None
# 3629      2000-09-01                      None                          None
# 3630      2000-09-01                      None                          None
#
#      offender_age_at_time_of_offense        lat       long  \
# 0                                 22  38.744944 -90.290619
# 1                                 29  38.654602 -90.201029
# 2                                 17  38.710232 -90.301116
# 3                                 18  38.564085 -90.313727
# 4                                 55  38.539049 -90.354750
# ...                              ...        ...        ...
# 3626                              27  38.565134 -90.239789
# 3627                              36  38.558506 -90.287920
# 3628                              36  38.558506 -90.287920
# 3629                              32  38.557082 -90.266005
# 3630                              32  38.557082 -90.266005
#
#                                                geometry
# 0     0101000020E61000007078107F999256C0BF66D6525A5F...
# 1     0101000020E6100000B4D0DBA8DD8C56C0064ED0FFC953...
# 2     0101000020E61000006DC2E57A459356C073EFD5E0E85A...
# 3     0101000020E6100000B24B271B149456C02D0DDDF03348...
# 4     0101000020E6100000F8FBB637B49656C03A3B6D92FF44...
# ...                                                 ...
# 3626  0101000020E6100000EE3189B4588F56C0C89003535648...
# 3627  0101000020E610000051F701486D9256C0554FE61F7D47...
# 3628  0101000020E610000051F701486D9256C0554FE61F7D47...
# 3629  0101000020E610000009523439069156C0A72E28734E47...
# 3630  0101000020E610000009523439069156C0A72E28734E47...
#
# [3631 rows x 23 columns]
