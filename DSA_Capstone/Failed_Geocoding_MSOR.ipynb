# %% [markdown]
# # Missouri Sex Offender Registry

# %% [markdown]
# Data acquisition, documentation, carpentry, geocoding, and database loading for Missouri Sex Offender Registry (MSOR) and supporting info.

# %%
# IMPORTS
import geopandas as gpd
import pandas as pd

# import os
# import urllib.request
# import requests
# import shutil
# from pathlib import Path
# from zipfile import ZipFile

import matplotlib.pyplot as plt
from matplotlib import pyplot

import folium

# from shapely.geometry import Point, Polygon

# from geopandas.tools import overlay

from geopy.geocoders import Nominatim # for geocoding

# import random # for obscuring sex offender names

# %%
# we need GeoAlchemy2 to run the geodataframe to_postgis method later

# %%
pip install GeoAlchemy2
# Out:
# Collecting GeoAlchemy2
#   Downloading https://files.pythonhosted.org/packages/df/b4/94b1f707dc89d107ac0a49a1f36a45b8b57812e603951f84bef999df3e3b/GeoAlchemy2-0.10.2-py2.py3-none-any.whl
# Requirement already satisfied: SQLAlchemy>=1.1 in /opt/conda/lib/python3.7/site-packages (from GeoAlchemy2) (1.4.22)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from GeoAlchemy2) (21.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from SQLAlchemy>=1.1->GeoAlchemy2) (4.6.1)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" in /opt/conda/lib/python3.7/site-packages (from SQLAlchemy>=1.1->GeoAlchemy2) (1.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->GeoAlchemy2) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->SQLAlchemy>=1.1->GeoAlchemy2) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->SQLAlchemy>=1.1->GeoAlchemy2) (3.10.0.0)
# Installing collected packages: GeoAlchemy2
# Successfully installed GeoAlchemy2-0.10.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# a few more imports specfic to the database process
import geoalchemy2 
import getpass

import psycopg2
import numpy
from psycopg2.extensions import adapt, register_adapter, AsIs

from sqlalchemy import create_engine

# %%
# get user password for connecting to the db
mypasswd = getpass.getpass()
# Out:
# ········

# %%
# set up db connection
conn = psycopg2.connect(database = 'cappsds_psmd39', 
                              user = 'psmd39', 
                              host = 'pgsql.dsa.lan',
                              password = mypasswd)

# %%
# establish cursor and read the existing tables
cursor = conn.cursor()

cursor.execute("""SELECT relname FROM pg_class WHERE relkind='r'
                  AND relname !~ '^(pg_|sql_)';""") # "rel" is short for relation.

tables = [i[0] for i in cursor.fetchall()] # A list() of tables.
tables.sort()
tables
# Out:
# ['country_borders',
#  'gadm_admin_borders',
#  'geonames_feature',
#  'msorfailedgeocoding',
#  'spatial_ref_sys',
#  'stlchildcare',
#  'stlnonrestrictedresidential',
#  'stlnonrestrictedresparcels',
#  'stlpubschools',
#  'stlpvtschools',
#  'stlresparcels',
#  'stlrestrictedflat',
#  'stlsexoffenders',
#  'stlzoning']

# %% [markdown]
# ## Failed geocoding
# There were a lot of sex offender registry entries that failed geocoding. Possible solutions:
# - Look for trends in the failed entries and work to resolve
# - Try another geocoder

# %% [markdown]
# ### Get the entries that failed geocoding out of the database
# In the prior notebook, we stored all these records in a dedicated table for easy access.

# %%
# test to make sure the load actually worked
# query the table and read data into a geodf 
sql = "select * from msorfailedgeocoding;"
msor_nogeo = pd.read_sql_query(sql, conn)
print(msor_nogeo.shape)
msor_nogeo.head()
# Out:
# (1334, 14)
#    index                  name                    address         city  st  \
# 0     10       ABDI, IBRAHIM A     3764 CHIPPEWA ST APT 8  SAINT LOUIS  MO
# 1     18  ABERNATHY, RANDELL L   3866 S SPRING AVE APT 1S  SAINT LOUIS  MO
# 2     40    ACKLEY, CLIFFORD D        3329 LAWN AVE APT 4  SAINT LOUIS  MO
# 3     41    ACKLEY, CLIFFORD D        3329 LAWN AVE APT 4  SAINT LOUIS  MO
# 4     99   ADAMS, QUINDARRYL L  4133 CLEVELAND AVE APT 1W  SAINT LOUIS  MO
#
#      zip         county                   offense  count compliant  tier  \
# 0  63116  ST LOUIS CITY     SEXUAL MISCONDUCT-3RD      1         Y     1
# 1  63116  ST LOUIS CITY      AGG CRIM SEX ASSAULT      2         Y     3
# 2  63139  ST LOUIS CITY                      RAPE      1         Y     3
# 3  63139  ST LOUIS CITY  STATUTORY RAPE-2ND DEGRE      1         Y     3
# 4  63110  ST LOUIS CITY            SEXUAL BATTERY      1         Y     1
#
#   date_of_birth                              full_address geocode
# 0    1981-09-08     3764 CHIPPEWA ST APT 8,SAINT LOUIS,MO    None
# 1    1969-07-30   3866 S SPRING AVE APT 1S,SAINT LOUIS,MO    None
# 2    1964-10-25        3329 LAWN AVE APT 4,SAINT LOUIS,MO    None
# 3    1964-10-25        3329 LAWN AVE APT 4,SAINT LOUIS,MO    None
# 4    1990-10-30  4133 CLEVELAND AVE APT 1W,SAINT LOUIS,MO    None

# %% [markdown]
# ### Set up the geocoder

# %%
# set up the geocoder
geolocator = Nominatim(timeout=10, user_agent = "myGeolocator")

# %%
# test out the geocoder with a single address
location = geolocator.geocode('120 CATALAN,ST LOUIS,MO')
print(location)
print((location.latitude, location.longitude))
# Out:
# St. Louis Skatium, 120, East Catalan Street, Patch, Saint Louis, Missouri, 63111, United States
# (38.5396446, -90.26550765004728)

# %% [markdown]
# ### THIS LOOKS PROMISING

# %%
# geocode_test_slice = msor_nogeo_test.sample(n=20)
geocode_test_slice = msor_nogeo.copy()
geocode_test_slice
# Out:
#       index                  name                        address         city  \
# 0        10       ABDI, IBRAHIM A         3764 CHIPPEWA ST APT 8  SAINT LOUIS
# 1        18  ABERNATHY, RANDELL L       3866 S SPRING AVE APT 1S  SAINT LOUIS
# 2        40    ACKLEY, CLIFFORD D            3329 LAWN AVE APT 4  SAINT LOUIS
# 3        41    ACKLEY, CLIFFORD D            3329 LAWN AVE APT 4  SAINT LOUIS
# 4        99   ADAMS, QUINDARRYL L      4133 CLEVELAND AVE APT 1W  SAINT LOUIS
# ...     ...                   ...                            ...          ...
# 1329  26006       YOUNG, TYRONE F           4962 THEKLA AVE FL 1  SAINT LOUIS
# 1330  26011      YOUNG, WILLIAM R           159 SHEPLEY DR APT 2  SAINT LOUIS
# 1331  26100     ZWEIFEL, JUDITH A  4447 CASTLEMAN AVE APT 1 WEST  SAINT LOUIS
# 1332  26101     ZWEIFEL, JUDITH A  4447 CASTLEMAN AVE APT 1 WEST  SAINT LOUIS
# 1333  26102     ZWEIFEL, JUDITH A  4447 CASTLEMAN AVE APT 1 WEST  SAINT LOUIS
#
#       st    zip         county                          offense  count  \
# 0     MO  63116  ST LOUIS CITY            SEXUAL MISCONDUCT-3RD      1
# 1     MO  63116  ST LOUIS CITY             AGG CRIM SEX ASSAULT      2
# 2     MO  63139  ST LOUIS CITY                             RAPE      1
# 3     MO  63139  ST LOUIS CITY         STATUTORY RAPE-2ND DEGRE      1
# 4     MO  63110  ST LOUIS CITY                   SEXUAL BATTERY      1
# ...   ..    ...            ...                              ...    ...
# 1329  MO  63115  ST LOUIS CITY           DEVIATE SEXUAL ASSAULT      1
# 1330  MO  63137       ST LOUIS                CHILD MOLESTATION      1
# 1331  MO  63110  ST LOUIS CITY          CHILD MOLEST-1ST DEGREE      1
# 1332  MO  63110  ST LOUIS CITY  STAT RAPE-1ST DEG-PERS UNDER 14      9
# 1333  MO  63110  ST LOUIS CITY  STAT SODOMY-1ST DEG-PERS UND 14     20
#
#      compliant  tier date_of_birth  \
# 0            Y     1    1981-09-08
# 1            Y     3    1969-07-30
# 2            Y     3    1964-10-25
# 3            Y     3    1964-10-25
# 4            Y     1    1990-10-30
# ...        ...   ...           ...
# 1329         Y     3    1965-06-30
# 1330         Y     3    1957-11-30
# 1331         Y     3    1968-10-16
# 1332         Y     3    1968-10-16
# 1333         Y     3    1968-10-16
#
#                                       full_address geocode
# 0            3764 CHIPPEWA ST APT 8,SAINT LOUIS,MO    None
# 1          3866 S SPRING AVE APT 1S,SAINT LOUIS,MO    None
# 2               3329 LAWN AVE APT 4,SAINT LOUIS,MO    None
# 3               3329 LAWN AVE APT 4,SAINT LOUIS,MO    None
# 4         4133 CLEVELAND AVE APT 1W,SAINT LOUIS,MO    None
# ...                                            ...     ...
# 1329           4962 THEKLA AVE FL 1,SAINT LOUIS,MO    None
# 1330           159 SHEPLEY DR APT 2,SAINT LOUIS,MO    None
# 1331  4447 CASTLEMAN AVE APT 1 WEST,SAINT LOUIS,MO    None
# 1332  4447 CASTLEMAN AVE APT 1 WEST,SAINT LOUIS,MO    None
# 1333  4447 CASTLEMAN AVE APT 1 WEST,SAINT LOUIS,MO    None
#
# [1334 rows x 14 columns]

# %%
# geocode_test_slice = geocode_test_slice.reset_index()

# %%
# copy the address to a new column and then remove the part that causes geocoding to fail
geocode_test_slice['new_address'] = geocode_test_slice['address']
geocode_test_slice['new_address'] = geocode_test_slice.address.str.split(' APT')

# the split (above) outputs a list of two elements: the part of the address before "APT" and the part after
# we only care about the part before
# convert those list items up into two columns, then keep the valuable column back in the original column
address_split = pd.DataFrame(geocode_test_slice["new_address"].to_list(), columns=['keep', 'trash'])
geocode_test_slice['new_address'] = address_split['keep']

geocode_test_slice[['address','city','st','zip','full_address','new_address']]
# Out:
#                             address         city  st    zip  \
# 0            3764 CHIPPEWA ST APT 8  SAINT LOUIS  MO  63116
# 1          3866 S SPRING AVE APT 1S  SAINT LOUIS  MO  63116
# 2               3329 LAWN AVE APT 4  SAINT LOUIS  MO  63139
# 3               3329 LAWN AVE APT 4  SAINT LOUIS  MO  63139
# 4         4133 CLEVELAND AVE APT 1W  SAINT LOUIS  MO  63110
# ...                             ...          ...  ..    ...
# 1329           4962 THEKLA AVE FL 1  SAINT LOUIS  MO  63115
# 1330           159 SHEPLEY DR APT 2  SAINT LOUIS  MO  63137
# 1331  4447 CASTLEMAN AVE APT 1 WEST  SAINT LOUIS  MO  63110
# 1332  4447 CASTLEMAN AVE APT 1 WEST  SAINT LOUIS  MO  63110
# 1333  4447 CASTLEMAN AVE APT 1 WEST  SAINT LOUIS  MO  63110
#
#                                       full_address           new_address
# 0            3764 CHIPPEWA ST APT 8,SAINT LOUIS,MO      3764 CHIPPEWA ST
# 1          3866 S SPRING AVE APT 1S,SAINT LOUIS,MO     3866 S SPRING AVE
# 2               3329 LAWN AVE APT 4,SAINT LOUIS,MO         3329 LAWN AVE
# 3               3329 LAWN AVE APT 4,SAINT LOUIS,MO         3329 LAWN AVE
# 4         4133 CLEVELAND AVE APT 1W,SAINT LOUIS,MO    4133 CLEVELAND AVE
# ...                                            ...                   ...
# 1329           4962 THEKLA AVE FL 1,SAINT LOUIS,MO  4962 THEKLA AVE FL 1
# 1330           159 SHEPLEY DR APT 2,SAINT LOUIS,MO        159 SHEPLEY DR
# 1331  4447 CASTLEMAN AVE APT 1 WEST,SAINT LOUIS,MO    4447 CASTLEMAN AVE
# 1332  4447 CASTLEMAN AVE APT 1 WEST,SAINT LOUIS,MO    4447 CASTLEMAN AVE
# 1333  4447 CASTLEMAN AVE APT 1 WEST,SAINT LOUIS,MO    4447 CASTLEMAN AVE
#
# [1334 rows x 6 columns]

# %%
# merge together street addres, city, and state to create the "full address"
geocode_test_slice['new_address'] = geocode_test_slice.new_address + "," + geocode_test_slice.city + "," + geocode_test_slice.st

# now remove some of the elements that trip up the geocoder, using the comma to avoid unwanted replacements elsewhere
geocode_test_slice['new_address'] = geocode_test_slice.new_address.str.replace(' RD,',',')
geocode_test_slice['new_address'] = geocode_test_slice.new_address.str.replace(' AVE,',',')
geocode_test_slice['new_address'] = geocode_test_slice.new_address.str.replace(' DR,',',')

# geocode_test_slice[['address','city','st','zip','full_address','new_address']]

# %%
# send the updated addresses back to the geocoder
geocode_test_slice['geocode'] = geocode_test_slice.new_address.apply(geolocator.geocode)

# %%
# check out how many values are still failing geocoding ("isnull == True")
geocode_test_slice['geocode'].isnull().value_counts()
# Out:
# False    903
# True     431
# Name: geocode, dtype: int64

# %%
geocode_test_slice[['address','full_address','new_address','geocode']]
# Out:
#                             address  \
# 0            3764 CHIPPEWA ST APT 8
# 1          3866 S SPRING AVE APT 1S
# 2               3329 LAWN AVE APT 4
# 3               3329 LAWN AVE APT 4
# 4         4133 CLEVELAND AVE APT 1W
# ...                             ...
# 1329           4962 THEKLA AVE FL 1
# 1330           159 SHEPLEY DR APT 2
# 1331  4447 CASTLEMAN AVE APT 1 WEST
# 1332  4447 CASTLEMAN AVE APT 1 WEST
# 1333  4447 CASTLEMAN AVE APT 1 WEST
#
#                                       full_address  \
# 0            3764 CHIPPEWA ST APT 8,SAINT LOUIS,MO
# 1          3866 S SPRING AVE APT 1S,SAINT LOUIS,MO
# 2               3329 LAWN AVE APT 4,SAINT LOUIS,MO
# 3               3329 LAWN AVE APT 4,SAINT LOUIS,MO
# 4         4133 CLEVELAND AVE APT 1W,SAINT LOUIS,MO
# ...                                            ...
# 1329           4962 THEKLA AVE FL 1,SAINT LOUIS,MO
# 1330           159 SHEPLEY DR APT 2,SAINT LOUIS,MO
# 1331  4447 CASTLEMAN AVE APT 1 WEST,SAINT LOUIS,MO
# 1332  4447 CASTLEMAN AVE APT 1 WEST,SAINT LOUIS,MO
# 1333  4447 CASTLEMAN AVE APT 1 WEST,SAINT LOUIS,MO
#
#                               new_address  \
# 0         3764 CHIPPEWA ST,SAINT LOUIS,MO
# 1            3866 S SPRING,SAINT LOUIS,MO
# 2                3329 LAWN,SAINT LOUIS,MO
# 3                3329 LAWN,SAINT LOUIS,MO
# 4           4133 CLEVELAND,SAINT LOUIS,MO
# ...                                   ...
# 1329  4962 THEKLA AVE FL 1,SAINT LOUIS,MO
# 1330           159 SHEPLEY,SAINT LOUIS,MO
# 1331        4447 CASTLEMAN,SAINT LOUIS,MO
# 1332        4447 CASTLEMAN,SAINT LOUIS,MO
# 1333        4447 CASTLEMAN,SAINT LOUIS,MO
#
#                                                 geocode
# 0     (3764, Chippewa Street, Dutchtown, Saint Louis...
# 1                                                  None
# 2     (3329, Lawn Avenue, North Hampton, Saint Louis...
# 3     (3329, Lawn Avenue, North Hampton, Saint Louis...
# 4     (4133, Cleveland Avenue, Shaw, Saint Louis, Mi...
# ...                                                 ...
# 1329                                               None
# 1330  (159, Shepley Drive, Glasgow Village, Saint Lo...
# 1331  (4447, Castleman Avenue, Southwest Garden, Tow...
# 1332  (4447, Castleman Avenue, Southwest Garden, Tow...
# 1333  (4447, Castleman Avenue, Southwest Garden, Tow...
#
# [1334 rows x 4 columns]

# %%
geocode_test_slice_nona = geocode_test_slice.dropna().copy()
geocode_test_slice_nona.shape
# Out:
# (903, 15)

# %%
# get the latitude and longitude values from the geodata column and put them in their own columns for easier plotting
geocode_test_slice_nona['lat'] = [g.latitude for g in geocode_test_slice_nona.geocode]
geocode_test_slice_nona['long'] = [g.longitude for g in geocode_test_slice_nona.geocode]

# %% [markdown]
# #### Render a map that shows all the entries we recovered!

# %%
# create a base map centered on St. Louis
map_sexoffenders2 = folium.Map(
    location=[38.627003, -90.3],
    tiles='cartodbpositron',
    zoom_start=11,
)

# add a marker for each childcare facility
# label each facility with its name
for i in range(0,len(geocode_test_slice_nona)):
   folium.Marker(
      location=[geocode_test_slice_nona.iloc[i]['lat'], geocode_test_slice_nona.iloc[i]['long']],
      popup=geocode_test_slice_nona.iloc[i]['offense']
   ).add_to(map_sexoffenders2)

# display the map
map_sexoffenders2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a63823dca3134c569f8d047681d364ba%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a63823dca3134c569f8d047681d364ba%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a63823dca3134c569f8d047681d364ba%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a63823dca3134c569f8d047681d364ba%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.627003%2C%20-90.3%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# look at how many entries are still failing
nogeo_after_pass_2 = geocode_test_slice[geocode_test_slice['geocode'].isna()].copy()
nogeo_after_pass_2
# Out:
#       index                  name                    address         city  st  \
# 1        18  ABERNATHY, RANDELL L   3866 S SPRING AVE APT 1S  SAINT LOUIS  MO
# 5       109      ADAMS, WILLIAM J       5340 GRANT ST FL 2ND  SAINT LOUIS  MO
# 9       212    ALDRIDGE, SAMUEL A  120 W CATALAN AVE APT 201     ST LOUIS  MO
# 10      213    ALDRIDGE, SAMUEL A  120 W CATALAN AVE APT 201     ST LOUIS  MO
# 11      214    ALDRIDGE, SAMUEL A  120 W CATALAN AVE APT 201     ST LOUIS  MO
# ...     ...                   ...                        ...          ...  ..
# 1325  25991         YOUNG, MARVIN      3922 GUSTINE AVE FL 1  SAINT LOUIS  MO
# 1326  25992         YOUNG, MARVIN      3922 GUSTINE AVE FL 1  SAINT LOUIS  MO
# 1327  25993         YOUNG, MARVIN      3922 GUSTINE AVE FL 1  SAINT LOUIS  MO
# 1328  25994         YOUNG, MARVIN      3922 GUSTINE AVE FL 1  SAINT LOUIS  MO
# 1329  26006       YOUNG, TYRONE F       4962 THEKLA AVE FL 1  SAINT LOUIS  MO
#
#         zip         county                          offense  count compliant  \
# 1     63116  ST LOUIS CITY             AGG CRIM SEX ASSAULT      2         Y
# 5     63107  ST LOUIS CITY  STAT SODOMY-1ST DEG-PERS UND 14      1         Y
# 9     63111  ST LOUIS CITY                     ATTEMPT RAPE      1         Y
# 10    63111  ST LOUIS CITY         CHLD MOLST-2ND DEG-INJRY      1         Y
# 11    63111  ST LOUIS CITY                             RAPE      1         Y
# ...     ...            ...                              ...    ...       ...
# 1325  63116  ST LOUIS CITY          CHILD MOLEST-1ST DEGREE      1         Y
# 1326  63116  ST LOUIS CITY           ENDANGER WELFARE CHILD      1         Y
# 1327  63116  ST LOUIS CITY   SEX MISC-1ST-PRIOR CONV/WEAPON      1         Y
# 1328  63116  ST LOUIS CITY         STATUTORY SODOMY-1ST DEG      2         Y
# 1329  63115  ST LOUIS CITY           DEVIATE SEXUAL ASSAULT      1         Y
#
#       tier date_of_birth                             full_address geocode  \
# 1        3    1969-07-30  3866 S SPRING AVE APT 1S,SAINT LOUIS,MO    None
# 5        3    1967-10-26      5340 GRANT ST FL 2ND,SAINT LOUIS,MO    None
# 9        3    1964-10-22    120 W CATALAN AVE APT 201,ST LOUIS,MO    None
# 10       3    1964-10-22    120 W CATALAN AVE APT 201,ST LOUIS,MO    None
# 11       3    1964-10-22    120 W CATALAN AVE APT 201,ST LOUIS,MO    None
# ...    ...           ...                                      ...     ...
# 1325     3    1955-10-22     3922 GUSTINE AVE FL 1,SAINT LOUIS,MO    None
# 1326     3    1955-10-22     3922 GUSTINE AVE FL 1,SAINT LOUIS,MO    None
# 1327     3    1955-10-22     3922 GUSTINE AVE FL 1,SAINT LOUIS,MO    None
# 1328     3    1955-10-22     3922 GUSTINE AVE FL 1,SAINT LOUIS,MO    None
# 1329     3    1965-06-30      4962 THEKLA AVE FL 1,SAINT LOUIS,MO    None
#
#                                new_address
# 1             3866 S SPRING,SAINT LOUIS,MO
# 5      5340 GRANT ST FL 2ND,SAINT LOUIS,MO
# 9                120 W CATALAN,ST LOUIS,MO
# 10               120 W CATALAN,ST LOUIS,MO
# 11               120 W CATALAN,ST LOUIS,MO
# ...                                    ...
# 1325  3922 GUSTINE AVE FL 1,SAINT LOUIS,MO
# 1326  3922 GUSTINE AVE FL 1,SAINT LOUIS,MO
# 1327  3922 GUSTINE AVE FL 1,SAINT LOUIS,MO
# 1328  3922 GUSTINE AVE FL 1,SAINT LOUIS,MO
# 1329   4962 THEKLA AVE FL 1,SAINT LOUIS,MO
#
# [431 rows x 15 columns]

# %%
# one remaining issue is addresses with floors listed e.g. "FL 1" or "FL 2ND"
# another issue is addresses with cardinal direction letters e.g. "N","S","E","W"

# %%
# test out the geocoder with a single address
location = geolocator.geocode('5340 GRANT ST,SAINT LOUIS,MO')
print(location)
print((location.latitude, location.longitude))
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-784a0fc3be21> in <module>
#       2 location = geolocator.geocode('3866 SPRING,SAINT LOUIS,MO')
#       3 print(location)
# ----> 4 print((location.latitude, location.longitude))
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
nogeo_after_pass_2 = nogeo_after_pass_2.reset_index()

# %%
# one remaining issue is addresses with floors listed e.g. "FL 1" or "FL 2ND"
# another issue is addresses with cardinal direction letters e.g. "N","S","E","W"

# copy the address to a new column and then remove the part that causes geocoding to fail

# set up a list containing the string elements we want to remove
to_remove = [' FL ',' APT',' NBR',' RM',' UNIT',' DEPT',' REAR']
tot_ct = 0

# copy the existing addresses to a new column to initialize the target of the for loop
nogeo_after_pass_2['new_address'] = nogeo_after_pass_2['address']
print("Dataframe has",len(nogeo_after_pass_2),"entries")

# loop through all the elements in the list, removing each from the address
for i in to_remove:
    # split() outputs a list of two elements: the part of the address before the match string [i] and the part after
    # we only care about the part before
    nogeo_after_pass_2['split'] = nogeo_after_pass_2['new_address'].str.split(i)
    # convert those list items into two columns in a new (temp) df, then store the usable column back in the original df
    address_split = pd.DataFrame(nogeo_after_pass_2['split'].to_list(), columns=['keep', 'trash'])
    # count how many items we modified
    loop_ct = address_split['trash'].notnull().sum()
    # keep a running total of the modifications we've made
    tot_ct = tot_ct + loop_ct
    # overwrite the "new_address" with the updated value. this can then be used in subsequent loops for new matches.
    nogeo_after_pass_2['new_address'] = address_split['keep']
    print('Removed "',i,'" from address',' (',loop_ct,' entries)',sep='')

print(tot_ct,'total modifications')

nogeo_after_pass_2[['zip','address','full_address','new_address']].head(25)
# Out:
# Dataframe has 431 entries
# Removed " FL " from address (173 entries)
# Removed " APT" from address (112 entries)
# Removed " NBR" from address (3 entries)
# Removed " RM" from address (53 entries)
# Removed " UNIT" from address (17 entries)
# Removed " DEPT" from address (1 entries)
# Removed " REAR" from address (2 entries)
# 361 total modifications
#       zip                    address  \
# 0   63116   3866 S SPRING AVE APT 1S
# 1   63107       5340 GRANT ST FL 2ND
# 2   63111  120 W CATALAN AVE APT 201
# 3   63111  120 W CATALAN AVE APT 201
# 4   63111  120 W CATALAN AVE APT 201
# 5   63111  120 W CATALAN AVE APT 201
# 6   63111      5001 IDAHO AVE FL 1ST
# 7   63104     1218 SOULARD ST FL 1ST
# 8   63104     1218 SOULARD ST FL 1ST
# 9   63107          1420 E LINTON AVE
# 10  63107          1420 E LINTON AVE
# 11  63107          1420 E LINTON AVE
# 12  63123     9733 CRAYFORD RD NBR H
# 13  63123     9733 CRAYFORD RD NBR H
# 14  63116   3918 KINGSLAND CT FL 1ST
# 15  63116   3918 KINGSLAND CT FL 1ST
# 16  63116    3119 OAK HILL AVE APT A
# 17  63116    3119 OAK HILL AVE APT A
# 18  63116    3119 OAK HILL AVE APT A
# 19  63116    3119 OAK HILL AVE APT A
# 20  63126     9428 EDDIE AND PARK RD
# 21  63116  4032 HYDRAULIC AVE FL 1ST
# 22  63111   5117 MINNESOTA AVE APT B
# 23  63114     1939 N WARSON RD APT A
# 24  63118     3437 MCKEAN AVE FL 1ST
#
#                                 full_address             new_address
# 0    3866 S SPRING AVE APT 1S,SAINT LOUIS,MO       3866 S SPRING AVE
# 1        5340 GRANT ST FL 2ND,SAINT LOUIS,MO           5340 GRANT ST
# 2      120 W CATALAN AVE APT 201,ST LOUIS,MO       120 W CATALAN AVE
# 3      120 W CATALAN AVE APT 201,ST LOUIS,MO       120 W CATALAN AVE
# 4      120 W CATALAN AVE APT 201,ST LOUIS,MO       120 W CATALAN AVE
# 5      120 W CATALAN AVE APT 201,ST LOUIS,MO       120 W CATALAN AVE
# 6       5001 IDAHO AVE FL 1ST,SAINT LOUIS,MO          5001 IDAHO AVE
# 7      1218 SOULARD ST FL 1ST,SAINT LOUIS,MO         1218 SOULARD ST
# 8      1218 SOULARD ST FL 1ST,SAINT LOUIS,MO         1218 SOULARD ST
# 9           1420 E LINTON AVE,SAINT LOUIS,MO       1420 E LINTON AVE
# 10          1420 E LINTON AVE,SAINT LOUIS,MO       1420 E LINTON AVE
# 11          1420 E LINTON AVE,SAINT LOUIS,MO       1420 E LINTON AVE
# 12     9733 CRAYFORD RD NBR H,SAINT LOUIS,MO        9733 CRAYFORD RD
# 13     9733 CRAYFORD RD NBR H,SAINT LOUIS,MO        9733 CRAYFORD RD
# 14   3918 KINGSLAND CT FL 1ST,SAINT LOUIS,MO       3918 KINGSLAND CT
# 15   3918 KINGSLAND CT FL 1ST,SAINT LOUIS,MO       3918 KINGSLAND CT
# 16    3119 OAK HILL AVE APT A,SAINT LOUIS,MO       3119 OAK HILL AVE
# 17    3119 OAK HILL AVE APT A,SAINT LOUIS,MO       3119 OAK HILL AVE
# 18    3119 OAK HILL AVE APT A,SAINT LOUIS,MO       3119 OAK HILL AVE
# 19    3119 OAK HILL AVE APT A,SAINT LOUIS,MO       3119 OAK HILL AVE
# 20     9428 EDDIE AND PARK RD,SAINT LOUIS,MO  9428 EDDIE AND PARK RD
# 21  4032 HYDRAULIC AVE FL 1ST,SAINT LOUIS,MO      4032 HYDRAULIC AVE
# 22   5117 MINNESOTA AVE APT B,SAINT LOUIS,MO      5117 MINNESOTA AVE
# 23     1939 N WARSON RD APT A,SAINT LOUIS,MO        1939 N WARSON RD
# 24     3437 MCKEAN AVE FL 1ST,SAINT LOUIS,MO         3437 MCKEAN AVE

# %%
# test out the geocoder with a single address
location = geolocator.geocode('7104 PAGE AVE,SAINT LOUIS,MO 	')
print(location)
print((location.latitude, location.longitude))
# Out:
# 7104, Page Avenue, Pagedale, Saint Louis County, Missouri, 63133, United States
# (38.676149571428574, -90.31305042857143)

# %%
# look at all the items we have not yet modified
nogeo_after_pass_2['match'] = nogeo_after_pass_2.address == nogeo_after_pass_2.new_address
nogeo_after_pass_2.loc[nogeo_after_pass_2['match'] == True][['zip','address','full_address','new_address']].tail(25)
# Out:
#        zip                         address  \
# 214  63121                    6606 BARR ST
# 215  63121                    6606 BARR ST
# 221  63110           4752 BOTANICAL 1ST FL
# 232  63128      4229 VALLEY CREST HILLS DR
# 241  63133      30 ARCHWAY MANOR DR LOT 30
# 246  63141              13143 DARTAGNAN CT
# 248  63121              4705 OAKRIDGE BLVD
# 249  63121              4705 OAKRIDGE BLVD
# 256  63123                4645 TIEMANN AVE
# 259  63102             1621 N FIRST STREET
# 289  63125                 224 BAUMANN AVE
# 314  63112  Compliant/Pending Registration
# 315  63122             2451 SAINT GILES RD
# 337  63101                        HOMELESS
# 340  63121              3800 OAKRIDGE BLVD
# 349  63118                3915A CALIFORNIA
# 350  63125     1 JEFFERSON BARRACKS RD BLD
# 358  63137                 128 MCALPINE DR
# 367  63113              4309 W MAFFITT AVE
# 376  63137                 647 ADRIAN SPUR
# 377  63137                 647 ADRIAN SPUR
# 378  63103                        HOMELESS
# 417  63118                  3822 S COMPTON
# 420  63106                 1135 BRISTOL LN
# 425  63107              2107 E COLLEGE AVE
#
#                                    full_address  \
# 214                 6606 BARR ST,SAINT LOUIS,MO
# 215                 6606 BARR ST,SAINT LOUIS,MO
# 221           4752 BOTANICAL 1ST FL,ST LOUIS,MO
# 232   4229 VALLEY CREST HILLS DR,SAINT LOUIS,MO
# 241   30 ARCHWAY MANOR DR LOT 30,SAINT LOUIS,MO
# 246           13143 DARTAGNAN CT,SAINT LOUIS,MO
# 248           4705 OAKRIDGE BLVD,SAINT LOUIS,MO
# 249           4705 OAKRIDGE BLVD,SAINT LOUIS,MO
# 256             4645 TIEMANN AVE,SAINT LOUIS,MO
# 259             1621 N FIRST STREET,ST LOUIS,MO
# 289              224 BAUMANN AVE,SAINT LOUIS,MO
# 314   Compliant/Pending Registration,ST LOUS,MO
# 315          2451 SAINT GILES RD,SAINT LOUIS,MO
# 337                     HOMELESS,SAINT LOUIS,MO
# 340           3800 OAKRIDGE BLVD,SAINT LOUIS,MO
# 349                3915A CALIFORNIA,ST LOUIS,MO
# 350  1 JEFFERSON BARRACKS RD BLD,SAINT LOUIS,MO
# 358              128 MCALPINE DR,SAINT LOUIS,MO
# 367           4309 W MAFFITT AVE,SAINT LOUIS,MO
# 376              647 ADRIAN SPUR,SAINT LOUIS,MO
# 377              647 ADRIAN SPUR,SAINT LOUIS,MO
# 378                        HOMELESS,ST LOUIS,MO
# 417                  3822 S COMPTON,ST LOUIS,MO
# 420              1135 BRISTOL LN,SAINT LOUIS,MO
# 425           2107 E COLLEGE AVE,SAINT LOUIS,MO
#
#                         new_address
# 214                    6606 BARR ST
# 215                    6606 BARR ST
# 221           4752 BOTANICAL 1ST FL
# 232      4229 VALLEY CREST HILLS DR
# 241      30 ARCHWAY MANOR DR LOT 30
# 246              13143 DARTAGNAN CT
# 248              4705 OAKRIDGE BLVD
# 249              4705 OAKRIDGE BLVD
# 256                4645 TIEMANN AVE
# 259             1621 N FIRST STREET
# 289                 224 BAUMANN AVE
# 314  Compliant/Pending Registration
# 315             2451 SAINT GILES RD
# 337                        HOMELESS
# 340              3800 OAKRIDGE BLVD
# 349                3915A CALIFORNIA
# 350     1 JEFFERSON BARRACKS RD BLD
# 358                 128 MCALPINE DR
# 367              4309 W MAFFITT AVE
# 376                 647 ADRIAN SPUR
# 377                 647 ADRIAN SPUR
# 378                        HOMELESS
# 417                  3822 S COMPTON
# 420                 1135 BRISTOL LN
# 425              2107 E COLLEGE AVE

# %%
# merge together street addres, city, and state to create the "full address"
geocode_test_slice['new_address'] = geocode_test_slice.new_address + "," + geocode_test_slice.city + "," + geocode_test_slice.st

# now remove some of the elements that trip up the geocoder, using the comma to avoid unwanted replacements elsewhere
geocode_test_slice['new_address'] = geocode_test_slice.new_address.str.replace(' RD,',',')
geocode_test_slice['new_address'] = geocode_test_slice.new_address.str.replace(' AVE,',',')
geocode_test_slice['new_address'] = geocode_test_slice.new_address.str.replace(' DR,',',')

# geocode_test_slice[['address','city','st','zip','full_address','new_address']]

# %% [markdown]
# #### Test for County == St Louis City

# %%
nogeo_after_pass_2.county.value_counts()
# Out:
# ST LOUIS CITY    365
# ST LOUIS          66
# Name: county, dtype: int64

# %%
nogeo_after_pass_2.loc[nogeo_after_pass_2['county'] == "ST LOUIS"]
# Out:
#      level_0  index                    name                        address  \
# 12        43    769          BACH, EDWARD E         9733 CRAYFORD RD NBR H
# 13        44    770          BACH, EDWARD E         9733 CRAYFORD RD NBR H
# 20        64   1301      BAXTER, JENNIFER L         9428 EDDIE AND PARK RD
# 23        76   1647       BERTHOLF, JASON M         1939 N WARSON RD APT A
# 49       142   2859          BROWN, ROMEL A            1405 DUNN RD RM 242
# ..       ...    ...                     ...                            ...
# 379     1173  23524  UNNERSTALL, NICHOLAS E  649 COEUR DE ROYALE DR UNIT B
# 388     1186  23779    VOGEL, CHRISTOPHER A     4121 SPRINGDALE AVE RM 104
# 396     1203  24031    WALLHAUSER, RONALD G            1857 UNION RD APT A
# 398     1213  24212   WASHINGTON, DEVONTA L       3325 W MILTON AVE UNIT B
# 399     1214  24213   WASHINGTON, DEVONTA L       3325 W MILTON AVE UNIT B
#
#             city  st    zip    county  \
# 12   SAINT LOUIS  MO  63123  ST LOUIS
# 13   SAINT LOUIS  MO  63123  ST LOUIS
# 20   SAINT LOUIS  MO  63126  ST LOUIS
# 23   SAINT LOUIS  MO  63114  ST LOUIS
# 49   SAINT LOUIS  MO  63138  ST LOUIS
# ..           ...  ..    ...       ...
# 379  SAINT LOUIS  MO  63141  ST LOUIS
# 388  SAINT LOUIS  MO  63134  ST LOUIS
# 396  SAINT LOUIS  MO  63125  ST LOUIS
# 398  SAINT LOUIS  MO  63114  ST LOUIS
# 399  SAINT LOUIS  MO  63114  ST LOUIS
#
#                                        offense  count compliant  tier  \
# 12                      DEVIATE SEXUAL ASSAULT      1         Y     3
# 13                              SEXUAL ASSAULT      2         Y     3
# 20   ENDANGERING WELFARE OF A CHILD-1ST DEGREE      3         Y     3
# 23             POSSESSION OF CHILD PORNOGRAPHY      1         Y     1
# 49                     CHILD MOLEST-1ST DEGREE      1         Y     3
# ..                                         ...    ...       ...   ...
# 379          ATMP ENTICE-ACTOR > 21/CHILD < 15      1         Y     2
# 388                                     SODOMY      1         Y     3
# 396                   STATUTORY SODOMY-2ND DEG      1         Y     2
# 398          SEX MISCD/ATMP INVL CHLD-1ST OFNS      1         Y     3
# 399            STATUTORY SODOMY - FIRST DEGREE      1         Y     3
#
#     date_of_birth                                  full_address geocode  \
# 12     1957-07-14         9733 CRAYFORD RD NBR H,SAINT LOUIS,MO    None
# 13     1957-07-14         9733 CRAYFORD RD NBR H,SAINT LOUIS,MO    None
# 20     1973-10-30         9428 EDDIE AND PARK RD,SAINT LOUIS,MO    None
# 23     1982-04-06         1939 N WARSON RD APT A,SAINT LOUIS,MO    None
# 49     1980-06-13            1405 DUNN RD RM 242,SAINT LOUIS,MO    None
# ..            ...                                           ...     ...
# 379    1984-10-13  649 COEUR DE ROYALE DR UNIT B,SAINT LOUIS,MO    None
# 388    1966-07-31     4121 SPRINGDALE AVE RM 104,SAINT LOUIS,MO    None
# 396    1956-04-01            1857 UNION RD APT A,SAINT LOUIS,MO    None
# 398    1992-06-14       3325 W MILTON AVE UNIT B,SAINT LOUIS,MO    None
# 399    1992-06-14       3325 W MILTON AVE UNIT B,SAINT LOUIS,MO    None
#
#                        new_address                new_address_split
# 12          9733 CRAYFORD RD NBR H         [9733 CRAYFORD RD NBR H]
# 13          9733 CRAYFORD RD NBR H         [9733 CRAYFORD RD NBR H]
# 20          9428 EDDIE AND PARK RD         [9428 EDDIE AND PARK RD]
# 23                1939 N WARSON RD           [1939 N WARSON RD,  A]
# 49             1405 DUNN RD RM 242            [1405 DUNN RD RM 242]
# ..                             ...                              ...
# 379  649 COEUR DE ROYALE DR UNIT B  [649 COEUR DE ROYALE DR UNIT B]
# 388     4121 SPRINGDALE AVE RM 104     [4121 SPRINGDALE AVE RM 104]
# 396                  1857 UNION RD              [1857 UNION RD,  A]
# 398       3325 W MILTON AVE UNIT B       [3325 W MILTON AVE UNIT B]
# 399       3325 W MILTON AVE UNIT B       [3325 W MILTON AVE UNIT B]
#
# [66 rows x 17 columns]

# %% [markdown]
# Need to remove apartment numbers FIRST, then push through geocoder.
# Then take remaining fails, remove AVE, ST, RD, then push through geocoder.

# %%
# geocode_test_slice.drop(['new_address'], inplace=True, axis=1)

# %% [markdown]
# # NEED TO CLEAN THE DATA MORE. SOME OFFENDERS ARE LISTED MULTIPLE TIMES.
# Could remove these duplicates by checking for unique combos from multiple columns
# - name
# - address
# - city
# - date of birth

# %% [markdown]
# # NEED TO CONSIDER ENTRIES WITHOUT ADDRESSES
#
# Addresses like "Compliant/Pending Registration" and "HOMELESS" will always fail geocoding. We can probably just ignore/drop these, but they need to be explained.

# %%
# load this data into a new table so we can easily continue working with it later

# Set up database connection engine
# FORMAT: engine = create_engine('postgresql://user:password@host:5432/')
engine = create_engine('postgresql://psmd39:Mizzou23?@pgsql.dsa.lan:5432/cappsds_psmd39', echo=False)

# GeoDataFrame to PostGIS
msor_nogeo.to_sql(
    con=engine,
    name="msorfailedgeocoding",
    if_exists='replace'
)
